# %%
import os
import pandas as pd
import numpy as np
import sqlalchemy as sql
from pathlib import Path
import questionary

# %%
path = "C://Users//17049//Desktop//Project//Project_1_TBD//IPODataFull.csv"
ipo_df = pd.read_csv(path, encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b0b0ec617d49> in <module>
#       1 path = "C://Users//17049//Desktop//Project//Project_1_TBD//IPODataFull.csv"
# ----> 2 ipo_df = pd.read_csv(path, encoding='latin1')
#
# ...

# %%
ipo_df.head()

# %%
ipo_df.drop(ipo_df.iloc[:, 14:1320], inplace = True, axis = 1)

ipo_df.head()

# %%
ipo_df.drop(ipo_df.iloc[:, -325:], inplace = True, axis = 1)
ipo_df.head()

# %%
ipo_df.drop(ipo_df.iloc[:, 3:5], inplace = True, axis = 1)

ipo_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e341530fd54e> in <module>
# ----> 1 ipo_df.drop(ipo_df.iloc[:, 3:5], inplace = True, axis = 1)
#       2
#       3 ipo_df.head()
#
# NameError: name 'ipo_df' is not defined

# %%
ipo_df.drop(ipo_df.iloc[:, 4:7], inplace = True, axis = 1)

ipo_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-32890ece29bf> in <module>
# ----> 1 ipo_df.drop(ipo_df.iloc[:, 4:7], inplace = True, axis = 1)
#       2
#       3 ipo_df.head()
#
# NameError: name 'ipo_df' is not defined

# %%
ipo_df.drop(ipo_df.iloc[:, -12:-2], inplace = True, axis = 1)

ipo_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ac34b7cd8957> in <module>
# ----> 1 ipo_df.drop(ipo_df.iloc[:, -12:-2], inplace = True, axis = 1)
#       2
#       3 ipo_df.head()
#
# NameError: name 'ipo_df' is not defined

# %%
ipo_df.drop(ipo_df.columns[[9, 11, 14]], inplace = True, axis = 1)

ipo_df
# Out:
#      Symbol  DaysBetterThanSP  daysProfit  Year  closeDay0  highDay0  \
# 0         A               122         249  1999    28.6358   33.5207
# 1       AAC               131         262  2014    18.5000   20.1000
# 2      AAOI               125         262  2013     9.9600   10.0900
# 3       AAP               128         261  2001    13.9000   14.4667
# 4       AAT               123         127  2011    21.2500   22.0000
# ...     ...               ...         ...   ...        ...       ...
# 3757   ZUMZ               139         261  2005    12.4350   12.5750
# 3758    ZUO                 5           7  2018    20.0000   21.8500
# 3759     ZX               102          25  2011     5.8500    6.2000
# 3760   ZYME               115          19  2017    13.0000   14.2500
# 3761   ZYNE               104          42  2015    16.2500   22.2500
#
#       openDay0  lowDay0  volumeDay0     MarketCap             Sector  \
# ...

# %%
#questionary.text("What year would you like to view IPO data for? (2011 thru 2018)").ask()

# %%
ipo_df.drop(ipo_df[ipo_df['Year'] < 2011].index, inplace = True)
ipo_df.sort_values(['Year', 'volumeDay0'], ascending = False)
ipo_group = ipo_df.groupby('Year').head(10).sort_values(['Year'])
ipo_group
# Out:
#     Symbol  DaysBetterThanSP  daysProfit  Year  closeDay0  highDay0  openDay0  \
# 76     AFT               113          30  2011     20.000    20.010     19.95
# 4      AAT               123         127  2011     21.250    22.000     21.18
# 122     AL               120          31  2011     27.950    28.400     26.75
# 89    AGRO               112         140  2011     12.000    12.110     10.75
# 43    ACST                23         261  2011     10.974    11.391     10.87
# ..     ...               ...         ...   ...        ...       ...       ...
# 575   CDLX                22          51  2018     13.370    13.900     11.10
# 91     AGS                36          61  2018     18.500    18.920     16.66
# 105   AIHS                17          25  2018      5.650     6.000      5.25
# 61     ADT                31          14  2018     12.390    12.970     12.00
# 595   CEPU                24          55  2018     17.700    18.250     16.10
#
# ...

# %%
ipo_group.drop(ipo_df.columns[[2, 4, 5, 6, 7, 9, 12]], inplace = True, axis = 1)

ipo_group
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af6a66ed739b> in <module>
# ----> 1 ipo_group.drop(ipo_df.columns[[2, 4, 5, 6, 7, 9, 12]], inplace = True, axis = 1)
#       2
#       3 ipo_group
#
# NameError: name 'ipo_group' is not defined
